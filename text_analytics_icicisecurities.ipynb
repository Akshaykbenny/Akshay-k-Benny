# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 4.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 61.5 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 39.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %%
pip install plotly_express
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.7.3)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.21.6)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (1.3.5)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (5.5.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (0.5.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from plotly_express) (0.12.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.0->plotly_express) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->plotly_express) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.1.0->plotly_express) (8.1.0)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1

# %%
pip install google_play_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
import pandas as pd
import numpy as np
import plotly_express as ps

# %%
from google_play_scraper import app, reviews_all, Sort

# %%
insta_project=reviews_all('com.icicisecurity.ifa', sleep_milliseconds=0, sort=Sort.NEWEST)

# %%
insta_project
# Out:
# [{'reviewId': '3bdd364a-018d-4c62-b69a-aa9441d4ad5c',
#   'userName': 'Jitu Prajapati',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_qArYkqqdbxBF5j75ROwxGRR9HY8swxkZnrMu05TU',
#   'content': "Doesn't open client account through open account section also not recieve link client mo and already opened account not show in real time",
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.3.0',
#   'at': datetime.datetime(2022, 10, 20, 12, 13),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'b01bf393-7a73-4008-a869-9da9024b98de',
#   'userName': 'Devesh Capital',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu2CocNcSJpA5IeRDkKj9cQnAYJ9zHilOOLbapA=mo',
#   'content': "Very bad experience.I didn't not see app like this, very old User interface, data not updated on time, no transactions history, what customer trade in a Day.",
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 9, 12, 19, 5, 56),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '4f4c410b-667f-4616-8f12-c7d551f99523',
#   'userName': 'Satyan Tenguriya',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_QUcSs31pC-CQ9Ghm_RDsYL9pzK4_dFa7zTu9T3Q',
#   'content': 'At least update this app and make user friendly for partners',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 9, 6, 13, 37, 49),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'e1944ccc-d52f-46d5-847d-ad47c2d8c95b',
#   'userName': 'Kavin singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-XejltOTMZcbVR7W0sYCCC_n1UF3cTAILF2ZRGPg',
#   'content': 'Fraud employees appealing in olx and telling lies in the name of relationship manager and opening demat account for their daily targets and trading themselves without our permission..',
#   'score': 1,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 8, 25, 16, 14, 56),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'ccb6dee1-d69d-4a6b-9004-3b2a413820d2',
#   'userName': 'KAUSHAL RAJ JAIN',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_IPIy2zFS5-PLO7Fy0647YKVuOrohJkNiXdls_Hw',
#   'content': 'Worst company',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 8, 21, 11, 57, 31),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'e4a2b46a-67d1-4243-a440-35d9efe85afc',
#   'userName': 'ABHIJEET TIWARI',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu291WcyVPire0xEGDXwEDO9mC5fteMmrVOwFE-b=mo',
#   'content': 'Employee is lier and zero support',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 8, 3, 17, 1, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '4c999dee-6d2b-4681-be38-22b8f7050b63',
#   'userName': 'Hrishikesh Garje',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9nNwELo1_J6EQJ_izTG12XcaFv75ZWs2uWL4L87A',
#   'content': 'Best',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 6, 22, 6, 3, 35),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'e7bb61aa-e52d-4a78-b460-0049ffc87ec3',
#   'userName': 'SUJAY SINGH',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu2lC224jUb3QJrBuSqmWOJh2qulxis7Q76zy4ox=mo',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 6, 15, 5, 1, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'fae02ecf-b292-4a3e-87ec-695fad6387da',
#   'userName': 'Mohammad Ashfaq',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_TkHPqkQLcjrFvF9sSbdvk_7TfhQwUlnOD7ngw0w',
#   'content': 'I forgot to my User id help me to recover.',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 5, 29, 2, 38, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'e5c380c8-5a6e-4360-aa4e-dc68a257fd4c',
#   'userName': 'Indranil Das',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8tqFz0jGCvBHim0r-YQcJJ2TUKGiuWQK3NkpAWDiU',
#   'content': 'বালের আপ',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 3, 24, 10, 56, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '3a10c28b-9a4d-4311-b67f-4619c3b1c459',
#   'userName': 'SANJAY RUMA GHOSH',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu92VDKZGL6A_DCWFZ36vkNrF0S70o1yHdC3K9-Z0g',
#   'content': "Very poor app. I am applying a partner code and they also approve my application, but after this they haven't sent me any partner ID and password in my mobile or email. Also there is no service for customer care to provide this. Never recommend for any business.",
#   'score': 1,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2022, 3, 23, 17, 14, 59),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '5fdd9cd7-f0a4-4cf6-b58e-3ff14274c983',
#   'userName': 'Akhtar Inamdar',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-8F-ernSXaA7DXNGwW3W7HuFAzcjt4P6HUUhgt',
#   'content': 'Not your customer support.',
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 2, 19, 3, 54, 31),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'b2b3d611-281b-46f0-bb26-482de7282784',
#   'userName': 'Vikas Dave',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu32QgQeZhanPIH9jCHy6RSVSmR_aQupUFlrgJ-A=mo',
#   'content': 'Not working properly and very confusing...pls make it issy for use',
#   'score': 3,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 1, 31, 4, 40, 31),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '30b2803a-b07c-49eb-b5e0-7fd3339feb3c',
#   'userName': 'Shailesh Tiwari',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8jv8NM3yCpWP1C47h_EmMJLkijFwwdARIglGqrVw',
#   'content': 'Is this app is working? If yes then contact me. Who is my RM? My user ID SHAI1984.',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 12, 16, 5, 51, 26),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'ada7d18f-07b6-4982-a031-c2139e9ef77f',
#   'userName': 'Nikhil Girme',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu3Aw8o3UXR7uDFcWRaCcCwmQhVustrE74GEt2OZ=mo',
#   'content': "Can't download..so difficult",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 12, 4, 12, 35, 29),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'ed3c9db6-e47f-4bd6-9863-e9da7dd661f3',
#   'userName': 'Sandeep Mohan',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_2TvIoVIHkbsPakKGt6g4K18MAJf9opj-OMdqraw',
#   'content': 'बकवास',
#   'score': 1,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 12, 3, 15, 52, 21),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'ef259fb5-5a2e-468b-9150-ee9fa1361ac2',
#   'userName': 'Ranveer jadhav',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8ikmLCZnpAyyV6ZnzkHZxp8tNgGECiUjKUVjb9',
#   'content': 'Fruitful',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 10, 30, 11, 28, 19),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '849c1127-f732-4793-b698-89a32e865ffd',
#   'userName': 'CA.Sunit Sethia, Burhanpur',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9Xk8zFBXUfpxgh7L4pRMFis-nDkNZMml5tW3GUUQ',
#   'content': "App is not working. It's totally failed",
#   'score': 1,
#   'thumbsUpCount': 40,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 9, 4, 13, 4, 44),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'c0633225-d687-4369-a8b6-85ec4083bc5a',
#   'userName': 'kanpuriya chacha',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-yt31p6k23OTZLh5w20ywiaY8PUpbp98rriPC9QQ',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 8, 13, 16, 21, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '58085f3b-4752-45c7-90c9-e4418cba05eb',
#   'userName': 'Mansi Gupta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9mtUk8LdR8jwhPGl9VltBjspns-J4XPLB5PWOvxw',
#   'content': "I didn't understand ho to use it",
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 7, 30, 18, 11, 22),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'de010c9b-7589-4fcf-9a16-e01b3daa0ba8',
#   'userName': 'Shivesh Shukla',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_YQUHuat19XixB9ByG5SrqFqswJk7mDRSD6fDL',
#   'content': 'Very good app... Working nicely...able to track everything 👍👍👍',
#   'score': 5,
#   'thumbsUpCount': 36,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 7, 27, 4, 32, 42),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '25aec9a1-bf39-4ac4-8be0-c147aca8df36',
#   'userName': 'YOR TIME',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9dPyzrYFQms4MKoGGPs5DWzO2KgMjK582wPc_9qA',
#   'content': 'Excellent',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 7, 26, 11, 1, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '0fb46dfc-d38f-4392-86c2-55e0ec389286',
#   'userName': 'Kushan Verma',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8z7gwPIvPpruzbTXvS_nbPpgGTlCvCGLj_pZK3',
#   'content': 'Good job',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 7, 10, 0, 47, 9),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '0bac4746-46e9-4398-b07e-694f30fda04f',
#   'userName': 'Vijay Bahadur Singh',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8QI_g2onu3ZYrVpOdhi5gLAbDsycbkD-M5MDK0ErI',
#   'content': 'ONE OF WORST APP FROM ICICISECURITIES',
#   'score': 1,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 6, 26, 13, 43, 16),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '6952b300-0b1c-42c4-a66e-74480847267f',
#   'userName': 'manoranjan dash',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu--srXDFspwnCAHganPRk0Ba0WJNM5h4E2gUbE1zSE',
#   'content': 'Such a pathetic app',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 6, 3, 19, 56, 22),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '50e50d10-cbb2-482f-b3a8-1ba109b3fdb3',
#   'userName': 'APS MANAGEMENT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-KtUa0wJrqYpqvGsOsmJwEoqY3RNSPSXvHBrj76w',
#   'content': 'Very bed 😡 not download this app',
#   'score': 1,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 5, 27, 18, 8, 31),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '6131a5b5-b3bd-40d3-9774-7241abae5935',
#   'userName': 'Razi Ahmad',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu2UaIdvVqFRjzEMwTdCdEkLq1j90gWwyFv8DlYy6w=mo',
#   'content': 'I am unable to login',
#   'score': 1,
#   'thumbsUpCount': 9,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 5, 25, 9, 49, 49),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '371f8107-2110-4a17-8f63-da1763b980dd',
#   'userName': 'sumita mahapatra',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu10uFgmqKmdA8_2NICLnWpAZKfgBwXCV-WrIKij=mo',
#   'content': 'Very very very very very very bad app',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 5, 25, 3, 25, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '9f6faa13-653e-453f-a7a3-e74c2364fa73',
#   'userName': 'Hitesh Jaiswal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9nz8VbAZ5TUyixsTldesinT788LvdiRM6RTPcISA',
#   'content': 'Very bed service no password reset no patnar support',
#   'score': 1,
#   'thumbsUpCount': 28,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 5, 19, 17, 38, 17),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '5c9725f6-a943-4ebf-8fe2-077bd1aae026',
#   'userName': 'Yogesh Laddha',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-3dCtMuZKxcLNDiWRe5pOpZbjIGT8JgKmndsKgwg',
#   'content': 'Will have to Wait for 24 Hours or 24 Days for the IFA Code Activation ?',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 5, 10, 10, 52, 28),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '390e8803-afbe-477b-be9c-cd66a68058a4',
#   'userName': 'preman nair',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu3cP6xTDEXMl7q3ERH4pTIhTAPNUc3NI1gKw8I1=mo',
#   'content': 'No option for Loan Business',
#   'score': 3,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 4, 30, 5, 19, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '0e4237cf-d26c-480a-9af7-a5670b54d879',
#   'userName': 'Sachin Hanwate',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_J61DOvqgD-7fzqVAtP_fQZnolgnFYzMFX2KnSfEo',
#   'content': 'Great',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.2.0',
#   'at': datetime.datetime(2021, 4, 29, 5, 48, 12),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'fd31cfc1-d82e-4962-8239-ac27212fe2c9',
#   'userName': 'Prabir Dutta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-UkUauj12ffo_mDchjrS620Ulc9zmw_cUqC0_Inw',
#   'content': 'Ok',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 4, 25, 16, 14, 34),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'f9eb164b-aaa7-4c95-9fc4-9d11fa32d370',
#   'userName': 'Mr Pankaj Hurmade',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8Sed7X9AEfCUfOotRV2xKbas0Im94vJ9asQcfysps',
#   'content': 'Not is batter aap',
#   'score': 3,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 4, 25, 10, 55, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'b62c1913-d12a-4cb8-ba4c-1324c3f2dcd3',
#   'userName': 'Mr. N Roy',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-gK77a727V_LsulCi6uVWkDX9_4Naa2ELBSQDMJA',
#   'content': 'Satisfied',
#   'score': 3,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 4, 21, 2, 14, 34),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'a8b3fd40-d2c1-480b-af95-cb2fd5519050',
#   'userName': 'sudhanshu shroti',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu_CGDzH3q1L-Cs0EiVJn_5tczSYsBxECMyilnyklZY',
#   'content': 'Icici channel not communicate after 1 month its worthless',
#   'score': 1,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 3, 21, 12, 25, 19),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '04bee4f9-c9b6-4e3a-8995-9de226d28dee',
#   'userName': 'Narendra doddamani',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-WgJLcGYBBiOV3T4X9FZsnR1SSTPAWr_5LFVzZhw',
#   'content': 'It is only for mutual fund (new sip) what about loan reference etc',
#   'score': 1,
#   'thumbsUpCount': 12,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 3, 16, 14, 57),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '7b574129-12c9-4256-8d0b-136d83999466',
#   'userName': 'PINTU KUMAR',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu1dhUdMhUcCLA0aiuco1wHHrQ8nNxTScf82ZEBBBw=mo',
#   'content': 'Veri nice',
#   'score': 5,
#   'thumbsUpCount': 4,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 2, 25, 16, 14, 40),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '72bf4d01-54fb-48ed-ae37-07b817af18bb',
#   'userName': 'Anirudh P K',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu3jXbbJbJHhiFm_CTkmGMYLhiuewafITuIUGjEU=mo',
#   'content': "I have registered to icici partners app and now I'm not able to login using my credentials and there is no support team to help me. Worst service from icici",
#   'score': 1,
#   'thumbsUpCount': 31,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 2, 16, 9, 44, 14),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '06c201f9-45ed-4a98-b1b2-c7f2f8cf41bc',
#   'userName': 'SUDARSAN CHENNOZUU',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu1H5ZXT6vT821l6NOFAm4nIBCqbYjj5vffX70vV=mo',
#   'content': 'allways getting server error while completing apolication very bad experiance',
#   'score': 1,
#   'thumbsUpCount': 48,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2021, 2, 3, 17, 38, 55),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'd6221717-fd86-4e7a-8657-8ff8e9895e03',
#   'userName': 'Yogesh Jadhav',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9cnXk5IenedujwKlA6xkUaTu3RYJZ_Km5klN72',
#   'content': 'Not working properly hence uninstall',
#   'score': 1,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 9, 5, 17, 19, 14),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'd13667c9-e55f-4687-bcd9-ba70065946b0',
#   'userName': 'Suraj Burnwal',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu-NuG3Pj76-uGS4Q04xCyfDeoO1DGNo-dSrareG-xM',
#   'content': 'App is very slow',
#   'score': 2,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2020, 8, 26, 10, 24, 53),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '01edd394-22d2-4800-9278-6f91da54d123',
#   'userName': 'PINAKI RANJAN SAHA',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8q48Nb7nTsKmOaP8bWOEAUSobdjLkTFYBg__sVcg',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2020, 6, 25, 12, 9, 46),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '58465724-16c0-478a-b1c3-7684c5044122',
#   'userName': 'MEHUL KORAT',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu9p7fx_UlB-FpU1LmEV1UNksuxqf1MMsrKkPvBpJg',
#   'content': 'Very bad exprince i am idirect partner on date 31 feb 2020 but still date my i direct partner app not open when i am trying every time shaw my panand dob is incorrect',
#   'score': 1,
#   'thumbsUpCount': 17,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 6, 10, 15, 58, 32),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '0aeda3da-fcbc-45df-bf44-8ea1129044e0',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'No Forget password options ... How to forget my password',
#   'score': 5,
#   'thumbsUpCount': 18,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2020, 4, 14, 15, 30, 39),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '109dc133-be0b-49d4-92d1-e33caa80ad82',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Traprance',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2020, 3, 29, 0, 51, 3),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '9021126d-a65d-4709-a428-f12c6b088d97',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I am not able to login',
#   'score': 1,
#   'thumbsUpCount': 10,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2020, 3, 4, 18, 25, 33),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '1606bddd-0e66-439b-85cd-d91832ffaa0a',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'nice',
#   'score': 3,
#   'thumbsUpCount': 7,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2019, 8, 1, 10, 28, 35),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'bb714e80-3f24-4eed-b09a-4ccb2108062f',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'best',
#   'score': 5,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2019, 2, 1, 8, 34, 44),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '290c41bd-ef88-4a9c-b127-ebc983e37c59',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Useful app for business partner of icici securities ltd.',
#   'score': 5,
#   'thumbsUpCount': 25,
#   'reviewCreatedVersion': '1.1.1',
#   'at': datetime.datetime(2018, 12, 14, 11, 32, 35),
#   'replyContent': None,
#   'repliedAt': None}]

# %%
df=pd.json_normalize(insta_project)

# %%
df.head()
# Out:
#                                reviewId          userName  \
# 0  3bdd364a-018d-4c62-b69a-aa9441d4ad5c    Jitu Prajapati
# 1  b01bf393-7a73-4008-a869-9da9024b98de    Devesh Capital
# 2  4f4c410b-667f-4616-8f12-c7d551f99523  Satyan Tenguriya
# 3  e1944ccc-d52f-46d5-847d-ad47c2d8c95b       Kavin singh
# 4  ccb6dee1-d69d-4a6b-9004-3b2a413820d2  KAUSHAL RAJ JAIN
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a/ALm5wu...
# 2  https://play-lh.googleusercontent.com/a-/ACNPE...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  Doesn't open client account through open accou...      3              2
# 1  Very bad experience.I didn't not see app like ...      1              1
# 2  At least update this app and make user friendl...      1              0
# 3  Fraud employees appealing in olx and telling l...      1              2
# 4                                      Worst company      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0                1.3.0 2022-10-20 12:13:00         None      None
# 1                1.2.0 2022-09-12 19:05:56         None      None
# 2                 None 2022-09-06 13:37:49         None      None
# 3                1.2.0 2022-08-25 16:14:56         None      None
# 4                 None 2022-08-21 11:57:31         None      None

# %%
df.score.value_counts()
# Out:
# 1    28
# 5    15
# 3     6
# 2     1
# Name: score, dtype: int64

# %%
df['score'].value_counts().sort_index().plot(kind="bar",title="reviews by stars",figsize=(10,5))

# %%
import nltk

# %%
import tqdm

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
from tqdm.notebook import tqdm

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sia=SentimentIntensityAnalyzer()

# %%
sia.polarity_scores("i am very happy")
# Out:
# {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6115}

# %%
df.head()
# Out:
#                                reviewId          userName  \
# 0  3bdd364a-018d-4c62-b69a-aa9441d4ad5c    Jitu Prajapati
# 1  b01bf393-7a73-4008-a869-9da9024b98de    Devesh Capital
# 2  4f4c410b-667f-4616-8f12-c7d551f99523  Satyan Tenguriya
# 3  e1944ccc-d52f-46d5-847d-ad47c2d8c95b       Kavin singh
# 4  ccb6dee1-d69d-4a6b-9004-3b2a413820d2  KAUSHAL RAJ JAIN
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...
# 1  https://play-lh.googleusercontent.com/a/ALm5wu...
# 2  https://play-lh.googleusercontent.com/a-/ACNPE...
# 3  https://play-lh.googleusercontent.com/a-/ACNPE...
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...
#
#                                              content  score  thumbsUpCount  \
# 0  Doesn't open client account through open accou...      3              2
# 1  Very bad experience.I didn't not see app like ...      1              1
# 2  At least update this app and make user friendl...      1              0
# 3  Fraud employees appealing in olx and telling l...      1              2
# 4                                      Worst company      1              0
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0                1.3.0 2022-10-20 12:13:00         None      None
# 1                1.2.0 2022-09-12 19:05:56         None      None
# 2                 None 2022-09-06 13:37:49         None      None
# 3                1.2.0 2022-08-25 16:14:56         None      None
# 4                 None 2022-08-21 11:57:31         None      None

# %%
result={}
for i, row in tqdm(df.iterrows(), total=len(df)):
  text=row["content"]
  myid=row["userName"]
  result[myid]=sia.polarity_scores(text)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
result
# Out:
# {'Jitu Prajapati': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Devesh Capital': {'neg': 0.261,
#   'neu': 0.739,
#   'pos': 0.0,
#   'compound': -0.7966},
#  'Satyan Tenguriya': {'neg': 0.0,
#   'neu': 0.758,
#   'pos': 0.242,
#   'compound': 0.4939},
#  'Kavin singh': {'neg': 0.202, 'neu': 0.798, 'pos': 0.0, 'compound': -0.765},
#  'KAUSHAL RAJ JAIN': {'neg': 0.804,
#   'neu': 0.196,
#   'pos': 0.0,
#   'compound': -0.6249},
#  'ABHIJEET TIWARI': {'neg': 0.0,
#   'neu': 0.649,
#   'pos': 0.351,
#   'compound': 0.4019},
#  'Hrishikesh Garje': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6369},
#  'SUJAY SINGH': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215},
#  'Mohammad Ashfaq': {'neg': 0.0,
#   'neu': 0.748,
#   'pos': 0.252,
#   'compound': 0.4019},
#  'Indranil Das': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'SANJAY RUMA GHOSH': {'neg': 0.142,
#   'neu': 0.778,
#   'pos': 0.08,
#   'compound': -0.3316},
#  'Akhtar Inamdar': {'neg': 0.429,
#   'neu': 0.571,
#   'pos': 0.0,
#   'compound': -0.3089},
#  'Vikas Dave': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Shailesh Tiwari': {'neg': 0.0,
#   'neu': 0.847,
#   'pos': 0.153,
#   'compound': 0.4696},
#  'Nikhil Girme': {'neg': 0.0, 'neu': 0.487, 'pos': 0.513, 'compound': 0.2755},
#  'Sandeep Mohan': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Ranveer jadhav': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'CA.Sunit Sethia, Burhanpur': {'neg': 0.375,
#   'neu': 0.625,
#   'pos': 0.0,
#   'compound': -0.5563},
#  'kanpuriya chacha': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4404},
#  'Mansi Gupta': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Shivesh Shukla': {'neg': 0.0,
#   'neu': 0.715,
#   'pos': 0.285,
#   'compound': 0.4927},
#  'YOR TIME': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5719},
#  'Kushan Verma': {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404},
#  'Vijay Bahadur Singh': {'neg': 0.451,
#   'neu': 0.549,
#   'pos': 0.0,
#   'compound': -0.6249},
#  'manoranjan dash': {'neg': 0.649,
#   'neu': 0.351,
#   'pos': 0.0,
#   'compound': -0.5719},
#  'APS MANAGEMENT': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Razi Ahmad': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'sumita mahapatra': {'neg': 0.382,
#   'neu': 0.618,
#   'pos': 0.0,
#   'compound': -0.6525},
#  'Hitesh Jaiswal': {'neg': 0.362,
#   'neu': 0.44,
#   'pos': 0.198,
#   'compound': -0.3021},
#  'Yogesh Laddha': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'preman nair': {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.296},
#  'Sachin Hanwate': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6249},
#  'Prabir Dutta': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296},
#  'Mr Pankaj Hurmade': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Mr. N Roy': {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.4215},
#  'sudhanshu shroti': {'neg': 0.293,
#   'neu': 0.707,
#   'pos': 0.0,
#   'compound': -0.4404},
#  'Narendra doddamani': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'PINTU KUMAR': {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'compound': 0.4215},
#  'Anirudh P K': {'neg': 0.172,
#   'neu': 0.681,
#   'pos': 0.147,
#   'compound': -0.2263},
#  'SUDARSAN CHENNOZUU': {'neg': 0.448,
#   'neu': 0.552,
#   'pos': 0.0,
#   'compound': -0.7574},
#  'Yogesh Jadhav': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'Suraj Burnwal': {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  'PINAKI RANJAN SAHA': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.4404},
#  'MEHUL KORAT': {'neg': 0.074, 'neu': 0.926, 'pos': 0.0, 'compound': -0.3392},
#  'A Google user': {'neg': 0.0, 'neu': 0.579, 'pos': 0.421, 'compound': 0.6249}}

# %%
pd.DataFrame(result)
# Out:
#           Jitu Prajapati  Devesh Capital  Satyan Tenguriya  Kavin singh  \
# neg                  0.0          0.2610            0.0000        0.202
# neu                  1.0          0.7390            0.7580        0.798
# pos                  0.0          0.0000            0.2420        0.000
# compound             0.0         -0.7966            0.4939       -0.765
#
#           KAUSHAL RAJ JAIN  ABHIJEET TIWARI  Hrishikesh Garje  SUJAY SINGH  \
# neg                 0.8040           0.0000            0.0000       0.0000
# neu                 0.1960           0.6490            0.0000       0.0000
# pos                 0.0000           0.3510            1.0000       1.0000
# compound           -0.6249           0.4019            0.6369       0.4215
#
#           Mohammad Ashfaq  Indranil Das  ...  sudhanshu shroti  \
# neg                0.0000           0.0  ...            0.2930
# neu                0.7480           1.0  ...            0.7070
# pos                0.2520           0.0  ...            0.0000
# compound           0.4019           0.0  ...           -0.4404
#
#           Narendra doddamani  PINTU KUMAR  Anirudh P K  SUDARSAN CHENNOZUU  \
# neg                      0.0       0.0000       0.1720              0.4480
# neu                      1.0       0.2630       0.6810              0.5520
# pos                      0.0       0.7370       0.1470              0.0000
# compound                 0.0       0.4215      -0.2263             -0.7574
#
#           Yogesh Jadhav  Suraj Burnwal  PINAKI RANJAN SAHA  MEHUL KORAT  \
# neg                 0.0            0.0              0.0000       0.0740
# neu                 1.0            1.0              0.0000       0.9260
# pos                 0.0            0.0              1.0000       0.0000
# compound            0.0            0.0              0.4404      -0.3392
#
#           A Google user
# neg              0.0000
# neu              0.5790
# pos              0.4210
# compound         0.6249
#
# [4 rows x 45 columns]

# %%
pd.DataFrame(result).T
# Out:
#                               neg    neu    pos  compound
# Jitu Prajapati              0.000  1.000  0.000    0.0000
# Devesh Capital              0.261  0.739  0.000   -0.7966
# Satyan Tenguriya            0.000  0.758  0.242    0.4939
# Kavin singh                 0.202  0.798  0.000   -0.7650
# KAUSHAL RAJ JAIN            0.804  0.196  0.000   -0.6249
# ABHIJEET TIWARI             0.000  0.649  0.351    0.4019
# Hrishikesh Garje            0.000  0.000  1.000    0.6369
# SUJAY SINGH                 0.000  0.000  1.000    0.4215
# Mohammad Ashfaq             0.000  0.748  0.252    0.4019
# Indranil Das                0.000  1.000  0.000    0.0000
# SANJAY RUMA GHOSH           0.142  0.778  0.080   -0.3316
# Akhtar Inamdar              0.429  0.571  0.000   -0.3089
# Vikas Dave                  0.000  1.000  0.000    0.0000
# Shailesh Tiwari             0.000  0.847  0.153    0.4696
# Nikhil Girme                0.000  0.487  0.513    0.2755
# Sandeep Mohan               0.000  1.000  0.000    0.0000
# Ranveer jadhav              0.000  1.000  0.000    0.0000
# CA.Sunit Sethia, Burhanpur  0.375  0.625  0.000   -0.5563
# kanpuriya chacha            0.000  0.000  1.000    0.4404
# Mansi Gupta                 0.000  1.000  0.000    0.0000
# Shivesh Shukla              0.000  0.715  0.285    0.4927
# YOR TIME                    0.000  0.000  1.000    0.5719
# Kushan Verma                0.000  0.256  0.744    0.4404
# Vijay Bahadur Singh         0.451  0.549  0.000   -0.6249
# manoranjan dash             0.649  0.351  0.000   -0.5719
# APS MANAGEMENT              0.000  1.000  0.000    0.0000
# Razi Ahmad                  0.000  1.000  0.000    0.0000
# sumita mahapatra            0.382  0.618  0.000   -0.6525
# Hitesh Jaiswal              0.362  0.440  0.198   -0.3021
# Yogesh Laddha               0.000  1.000  0.000    0.0000
# preman nair                 0.355  0.645  0.000   -0.2960
# Sachin Hanwate              0.000  0.000  1.000    0.6249
# Prabir Dutta                0.000  0.000  1.000    0.2960
# Mr Pankaj Hurmade           0.000  1.000  0.000    0.0000
# Mr. N Roy                   0.000  0.000  1.000    0.4215
# sudhanshu shroti            0.293  0.707  0.000   -0.4404
# Narendra doddamani          0.000  1.000  0.000    0.0000
# PINTU KUMAR                 0.000  0.263  0.737    0.4215
# Anirudh P K                 0.172  0.681  0.147   -0.2263
# SUDARSAN CHENNOZUU          0.448  0.552  0.000   -0.7574
# Yogesh Jadhav               0.000  1.000  0.000    0.0000
# Suraj Burnwal               0.000  1.000  0.000    0.0000
# PINAKI RANJAN SAHA          0.000  0.000  1.000    0.4404
# MEHUL KORAT                 0.074  0.926  0.000   -0.3392
# A Google user               0.000  0.579  0.421    0.6249

# %%
vaders=pd.DataFrame(result).T
vaders=vaders.reset_index().rename(columns={"index":"userName"})
vaders=vaders.merge(df, how="left")

# %%
vaders
# Out:
#                       userName    neg    neu    pos  compound  \
# 0               Jitu Prajapati  0.000  1.000  0.000    0.0000
# 1               Devesh Capital  0.261  0.739  0.000   -0.7966
# 2             Satyan Tenguriya  0.000  0.758  0.242    0.4939
# 3                  Kavin singh  0.202  0.798  0.000   -0.7650
# 4             KAUSHAL RAJ JAIN  0.804  0.196  0.000   -0.6249
# 5              ABHIJEET TIWARI  0.000  0.649  0.351    0.4019
# 6             Hrishikesh Garje  0.000  0.000  1.000    0.6369
# 7                  SUJAY SINGH  0.000  0.000  1.000    0.4215
# 8              Mohammad Ashfaq  0.000  0.748  0.252    0.4019
# 9                 Indranil Das  0.000  1.000  0.000    0.0000
# 10           SANJAY RUMA GHOSH  0.142  0.778  0.080   -0.3316
# 11              Akhtar Inamdar  0.429  0.571  0.000   -0.3089
# 12                  Vikas Dave  0.000  1.000  0.000    0.0000
# 13             Shailesh Tiwari  0.000  0.847  0.153    0.4696
# 14                Nikhil Girme  0.000  0.487  0.513    0.2755
# 15               Sandeep Mohan  0.000  1.000  0.000    0.0000
# 16              Ranveer jadhav  0.000  1.000  0.000    0.0000
# 17  CA.Sunit Sethia, Burhanpur  0.375  0.625  0.000   -0.5563
# 18            kanpuriya chacha  0.000  0.000  1.000    0.4404
# 19                 Mansi Gupta  0.000  1.000  0.000    0.0000
# 20              Shivesh Shukla  0.000  0.715  0.285    0.4927
# 21                    YOR TIME  0.000  0.000  1.000    0.5719
# 22                Kushan Verma  0.000  0.256  0.744    0.4404
# 23         Vijay Bahadur Singh  0.451  0.549  0.000   -0.6249
# 24             manoranjan dash  0.649  0.351  0.000   -0.5719
# 25              APS MANAGEMENT  0.000  1.000  0.000    0.0000
# 26                  Razi Ahmad  0.000  1.000  0.000    0.0000
# 27            sumita mahapatra  0.382  0.618  0.000   -0.6525
# 28              Hitesh Jaiswal  0.362  0.440  0.198   -0.3021
# 29               Yogesh Laddha  0.000  1.000  0.000    0.0000
# 30                 preman nair  0.355  0.645  0.000   -0.2960
# 31              Sachin Hanwate  0.000  0.000  1.000    0.6249
# 32                Prabir Dutta  0.000  0.000  1.000    0.2960
# 33           Mr Pankaj Hurmade  0.000  1.000  0.000    0.0000
# 34                   Mr. N Roy  0.000  0.000  1.000    0.4215
# 35            sudhanshu shroti  0.293  0.707  0.000   -0.4404
# 36          Narendra doddamani  0.000  1.000  0.000    0.0000
# 37                 PINTU KUMAR  0.000  0.263  0.737    0.4215
# 38                 Anirudh P K  0.172  0.681  0.147   -0.2263
# 39          SUDARSAN CHENNOZUU  0.448  0.552  0.000   -0.7574
# 40               Yogesh Jadhav  0.000  1.000  0.000    0.0000
# 41               Suraj Burnwal  0.000  1.000  0.000    0.0000
# 42          PINAKI RANJAN SAHA  0.000  0.000  1.000    0.4404
# 43                 MEHUL KORAT  0.074  0.926  0.000   -0.3392
# 44               A Google user  0.000  0.579  0.421    0.6249
# 45               A Google user  0.000  0.579  0.421    0.6249
# 46               A Google user  0.000  0.579  0.421    0.6249
# 47               A Google user  0.000  0.579  0.421    0.6249
# 48               A Google user  0.000  0.579  0.421    0.6249
# 49               A Google user  0.000  0.579  0.421    0.6249
#
#                                 reviewId  \
# 0   3bdd364a-018d-4c62-b69a-aa9441d4ad5c
# 1   b01bf393-7a73-4008-a869-9da9024b98de
# 2   4f4c410b-667f-4616-8f12-c7d551f99523
# 3   e1944ccc-d52f-46d5-847d-ad47c2d8c95b
# 4   ccb6dee1-d69d-4a6b-9004-3b2a413820d2
# 5   e4a2b46a-67d1-4243-a440-35d9efe85afc
# 6   4c999dee-6d2b-4681-be38-22b8f7050b63
# 7   e7bb61aa-e52d-4a78-b460-0049ffc87ec3
# 8   fae02ecf-b292-4a3e-87ec-695fad6387da
# 9   e5c380c8-5a6e-4360-aa4e-dc68a257fd4c
# 10  3a10c28b-9a4d-4311-b67f-4619c3b1c459
# 11  5fdd9cd7-f0a4-4cf6-b58e-3ff14274c983
# 12  b2b3d611-281b-46f0-bb26-482de7282784
# 13  30b2803a-b07c-49eb-b5e0-7fd3339feb3c
# 14  ada7d18f-07b6-4982-a031-c2139e9ef77f
# 15  ed3c9db6-e47f-4bd6-9863-e9da7dd661f3
# 16  ef259fb5-5a2e-468b-9150-ee9fa1361ac2
# 17  849c1127-f732-4793-b698-89a32e865ffd
# 18  c0633225-d687-4369-a8b6-85ec4083bc5a
# 19  58085f3b-4752-45c7-90c9-e4418cba05eb
# 20  de010c9b-7589-4fcf-9a16-e01b3daa0ba8
# 21  25aec9a1-bf39-4ac4-8be0-c147aca8df36
# 22  0fb46dfc-d38f-4392-86c2-55e0ec389286
# 23  0bac4746-46e9-4398-b07e-694f30fda04f
# 24  6952b300-0b1c-42c4-a66e-74480847267f
# 25  50e50d10-cbb2-482f-b3a8-1ba109b3fdb3
# 26  6131a5b5-b3bd-40d3-9774-7241abae5935
# 27  371f8107-2110-4a17-8f63-da1763b980dd
# 28  9f6faa13-653e-453f-a7a3-e74c2364fa73
# 29  5c9725f6-a943-4ebf-8fe2-077bd1aae026
# 30  390e8803-afbe-477b-be9c-cd66a68058a4
# 31  0e4237cf-d26c-480a-9af7-a5670b54d879
# 32  fd31cfc1-d82e-4962-8239-ac27212fe2c9
# 33  f9eb164b-aaa7-4c95-9fc4-9d11fa32d370
# 34  b62c1913-d12a-4cb8-ba4c-1324c3f2dcd3
# 35  a8b3fd40-d2c1-480b-af95-cb2fd5519050
# 36  04bee4f9-c9b6-4e3a-8995-9de226d28dee
# 37  7b574129-12c9-4256-8d0b-136d83999466
# 38  72bf4d01-54fb-48ed-ae37-07b817af18bb
# 39  06c201f9-45ed-4a98-b1b2-c7f2f8cf41bc
# 40  d6221717-fd86-4e7a-8657-8ff8e9895e03
# 41  d13667c9-e55f-4687-bcd9-ba70065946b0
# 42  01edd394-22d2-4800-9278-6f91da54d123
# 43  58465724-16c0-478a-b1c3-7684c5044122
# 44  0aeda3da-fcbc-45df-bf44-8ea1129044e0
# 45  109dc133-be0b-49d4-92d1-e33caa80ad82
# 46  9021126d-a65d-4709-a428-f12c6b088d97
# 47  1606bddd-0e66-439b-85cd-d91832ffaa0a
# 48  bb714e80-3f24-4eed-b09a-4ccb2108062f
# 49  290c41bd-ef88-4a9c-b127-ebc983e37c59
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ACNPE...
# 1   https://play-lh.googleusercontent.com/a/ALm5wu...
# 2   https://play-lh.googleusercontent.com/a-/ACNPE...
# 3   https://play-lh.googleusercontent.com/a-/ACNPE...
# 4   https://play-lh.googleusercontent.com/a-/ACNPE...
# 5   https://play-lh.googleusercontent.com/a/ALm5wu...
# 6   https://play-lh.googleusercontent.com/a-/ACNPE...
# 7   https://play-lh.googleusercontent.com/a/ALm5wu...
# 8   https://play-lh.googleusercontent.com/a-/ACNPE...
# 9   https://play-lh.googleusercontent.com/a-/ACNPE...
# 10  https://play-lh.googleusercontent.com/a-/ACNPE...
# 11  https://play-lh.googleusercontent.com/a-/ACNPE...
# 12  https://play-lh.googleusercontent.com/a/ALm5wu...
# 13  https://play-lh.googleusercontent.com/a-/ACNPE...
# 14  https://play-lh.googleusercontent.com/a/ALm5wu...
# 15  https://play-lh.googleusercontent.com/a-/ACNPE...
# 16  https://play-lh.googleusercontent.com/a-/ACNPE...
# 17  https://play-lh.googleusercontent.com/a-/ACNPE...
# 18  https://play-lh.googleusercontent.com/a-/ACNPE...
# 19  https://play-lh.googleusercontent.com/a-/ACNPE...
# 20  https://play-lh.googleusercontent.com/a-/ACNPE...
# 21  https://play-lh.googleusercontent.com/a-/ACNPE...
# 22  https://play-lh.googleusercontent.com/a-/ACNPE...
# 23  https://play-lh.googleusercontent.com/a-/ACNPE...
# 24  https://play-lh.googleusercontent.com/a-/ACNPE...
# 25  https://play-lh.googleusercontent.com/a-/ACNPE...
# 26  https://play-lh.googleusercontent.com/a/ALm5wu...
# 27  https://play-lh.googleusercontent.com/a/ALm5wu...
# 28  https://play-lh.googleusercontent.com/a-/ACNPE...
# 29  https://play-lh.googleusercontent.com/a-/ACNPE...
# 30  https://play-lh.googleusercontent.com/a/ALm5wu...
# 31  https://play-lh.googleusercontent.com/a-/ACNPE...
# 32  https://play-lh.googleusercontent.com/a-/ACNPE...
# 33  https://play-lh.googleusercontent.com/a-/ACNPE...
# 34  https://play-lh.googleusercontent.com/a-/ACNPE...
# 35  https://play-lh.googleusercontent.com/a-/ACNPE...
# 36  https://play-lh.googleusercontent.com/a-/ACNPE...
# 37  https://play-lh.googleusercontent.com/a/ALm5wu...
# 38  https://play-lh.googleusercontent.com/a/ALm5wu...
# 39  https://play-lh.googleusercontent.com/a/ALm5wu...
# 40  https://play-lh.googleusercontent.com/a-/ACNPE...
# 41  https://play-lh.googleusercontent.com/a-/ACNPE...
# 42  https://play-lh.googleusercontent.com/a-/ACNPE...
# 43  https://play-lh.googleusercontent.com/a-/ACNPE...
# 44  https://play-lh.googleusercontent.com/EGemoI2N...
# 45  https://play-lh.googleusercontent.com/EGemoI2N...
# 46  https://play-lh.googleusercontent.com/EGemoI2N...
# 47  https://play-lh.googleusercontent.com/EGemoI2N...
# 48  https://play-lh.googleusercontent.com/EGemoI2N...
# 49  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                               content  score  thumbsUpCount  \
# 0   Doesn't open client account through open accou...      3              2
# 1   Very bad experience.I didn't not see app like ...      1              1
# 2   At least update this app and make user friendl...      1              0
# 3   Fraud employees appealing in olx and telling l...      1              2
# 4                                       Worst company      1              0
# 5                   Employee is lier and zero support      1              0
# 6                                                Best      5              0
# 7                                                Nice      5              0
# 8          I forgot to my User id help me to recover.      1              0
# 9                                            বালের আপ      1              0
# 10  Very poor app. I am applying a partner code an...      1             16
# 11                         Not your customer support.      1              5
# 12  Not working properly and very confusing...pls ...      3              9
# 13  Is this app is working? If yes then contact me...      1              3
# 14                       Can't download..so difficult      1              3
# 15                                              बकवास      1              1
# 16                                           Fruitful      5              3
# 17            App is not working. It's totally failed      1             40
# 18                                               Good      5              1
# 19                   I didn't understand ho to use it      1              3
# 20  Very good app... Working nicely...able to trac...      5             36
# 21                                          Excellent      5              2
# 22                                           Good job      5              2
# 23              ONE OF WORST APP FROM ICICISECURITIES      1              4
# 24                                Such a pathetic app      1              3
# 25                   Very bed 😡 not download this app      1              5
# 26                               I am unable to login      1              9
# 27              Very very very very very very bad app      1              3
# 28  Very bed service no password reset no patnar s...      1             28
# 29  Will have to Wait for 24 Hours or 24 Days for ...      1              3
# 30                        No option for Loan Business      3              5
# 31                                              Great      5              1
# 32                                                 Ok      5              5
# 33                                  Not is batter aap      3              3
# 34                                          Satisfied      3              4
# 35  Icici channel not communicate after 1 month it...      1              3
# 36  It is only for mutual fund (new sip) what abou...      1             12
# 37                                          Veri nice      5              4
# 38  I have registered to icici partners app and no...      1             31
# 39  allways getting server error while completing ...      1             48
# 40               Not working properly hence uninstall      1              7
# 41                                   App is very slow      2              5
# 42                                               Good      5              3
# 43  Very bad exprince i am idirect partner on date...      1             17
# 44  No Forget password options ... How to forget m...      5             18
# 45                                          Traprance      5              3
# 46                             I am not able to login      1             10
# 47                                               nice      3              7
# 48                                               best      5             11
# 49  Useful app for business partner of icici secur...      5             25
#
#    reviewCreatedVersion                  at replyContent repliedAt
# 0                 1.3.0 2022-10-20 12:13:00         None      None
# 1                 1.2.0 2022-09-12 19:05:56         None      None
# 2                  None 2022-09-06 13:37:49         None      None
# 3                 1.2.0 2022-08-25 16:14:56         None      None
# 4                  None 2022-08-21 11:57:31         None      None
# 5                 1.2.0 2022-08-03 17:01:15         None      None
# 6                  None 2022-06-22 06:03:35         None      None
# 7                  None 2022-06-15 05:01:15         None      None
# 8                 1.2.0 2022-05-29 02:38:16         None      None
# 9                 1.2.0 2022-03-24 10:56:16         None      None
# 10                1.2.0 2022-03-23 17:14:59         None      None
# 11                 None 2022-02-19 03:54:31         None      None
# 12                 None 2022-01-31 04:40:31         None      None
# 13                1.2.0 2021-12-16 05:51:26         None      None
# 14                1.2.0 2021-12-04 12:35:29         None      None
# 15                1.2.0 2021-12-03 15:52:21         None      None
# 16                1.2.0 2021-10-30 11:28:19         None      None
# 17                1.2.0 2021-09-04 13:04:44         None      None
# 18                 None 2021-08-13 16:21:15         None      None
# 19                 None 2021-07-30 18:11:22         None      None
# 20                 None 2021-07-27 04:32:42         None      None
# 21                1.2.0 2021-07-26 11:01:39         None      None
# 22                1.2.0 2021-07-10 00:47:09         None      None
# 23                 None 2021-06-26 13:43:16         None      None
# 24                1.2.0 2021-06-03 19:56:22         None      None
# 25                 None 2021-05-27 18:08:31         None      None
# 26                1.2.0 2021-05-25 09:49:49         None      None
# 27                 None 2021-05-25 03:25:39         None      None
# 28                1.2.0 2021-05-19 17:38:17         None      None
# 29                1.2.0 2021-05-10 10:52:28         None      None
# 30                1.2.0 2021-04-30 05:19:01         None      None
# 31                1.2.0 2021-04-29 05:48:12         None      None
# 32                1.1.1 2021-04-25 16:14:34         None      None
# 33                 None 2021-04-25 10:55:01         None      None
# 34                 None 2021-04-21 02:14:34         None      None
# 35                1.1.1 2021-03-21 12:25:19         None      None
# 36                1.1.1 2021-03-16 14:57:00         None      None
# 37                1.1.1 2021-02-25 16:14:40         None      None
# 38                1.1.1 2021-02-16 09:44:14         None      None
# 39                1.1.1 2021-02-03 17:38:55         None      None
# 40                 None 2020-09-05 17:19:14         None      None
# 41                1.1.1 2020-08-26 10:24:53         None      None
# 42                1.1.1 2020-06-25 12:09:46         None      None
# 43                 None 2020-06-10 15:58:32         None      None
# 44                1.1.1 2020-04-14 15:30:39         None      None
# 45                 None 2020-03-29 00:51:03         None      None
# 46                1.1.1 2020-03-04 18:25:33         None      None
# 47                1.1.1 2019-08-01 10:28:35         None      None
# 48                1.1.1 2019-02-01 08:34:44         None      None
# 49                1.1.1 2018-12-14 11:32:35         None      None

# %%
import seaborn as sns

# %%
ax=sns.barplot(data=vaders,x="score",y="compound")
ax.set_title("compound score by icici securities")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4bbb3a2f0fb4> in <module>
#       1 ax=sns.barplot(data=vaders,x="score",y="compound")
#       2 ax.set_title("compound score by icici securities")
# ----> 3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(data=vaders,x="score",y="pos")

# %%
sns.barplot(data=vaders,x="score",y="neu")

# %%
sns.barplot(data=vaders,x="score",y="neg")

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
model="siebert/sentiment-roberta-large-english"
tokenizer=AutoTokenizer.from_pretrained(model)
model=AutoModelForSequenceClassification.from_pretrained(model)
# Out:
# Downloading:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/687 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42G [00:00<?, ?B/s]

# %%
tokenizer("it is really good",return_tensors="pt")
# Out:
# {'input_ids': tensor([[  0, 405,  16, 269, 205,   2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
encoded_text=tokenizer(text,return_tensors="pt")
output=model(**encoded_text)
scores=output[0][0].detach().numpy()
scores=softmax(scores)
scores
# Out:
# array([0.00163421, 0.99836576], dtype=float32)

# %%
scores_dict={
    "roberta_neg":scores[0],
    "roberta_pos":scores[1],
}

# %%
print(scores_dict)
# Out:
# {'roberta_neg': 0.999512, 'roberta_pos': 0.00048778442}

# %%
def polarity_scores_roberta(text):
  return(scores_dict)

# %%
result={}
for i, row in tqdm(df.iterrows(), total=len(df)):
  text=row["content"]
  myid=row["userName"]
  vader_results=sia.polarity_scores(text)
  roberta_results=polarity_scores_roberta(text)
  both={**vader_results,**roberta_results}
  result[myid]=both
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
result
# Out:
# {'Jitu Prajapati': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Devesh Capital': {'neg': 0.261,
#   'neu': 0.739,
#   'pos': 0.0,
#   'compound': -0.7966,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Satyan Tenguriya': {'neg': 0.0,
#   'neu': 0.758,
#   'pos': 0.242,
#   'compound': 0.4939,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Kavin singh': {'neg': 0.202,
#   'neu': 0.798,
#   'pos': 0.0,
#   'compound': -0.765,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'KAUSHAL RAJ JAIN': {'neg': 0.804,
#   'neu': 0.196,
#   'pos': 0.0,
#   'compound': -0.6249,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'ABHIJEET TIWARI': {'neg': 0.0,
#   'neu': 0.649,
#   'pos': 0.351,
#   'compound': 0.4019,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Hrishikesh Garje': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.6369,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'SUJAY SINGH': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.4215,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Mohammad Ashfaq': {'neg': 0.0,
#   'neu': 0.748,
#   'pos': 0.252,
#   'compound': 0.4019,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Indranil Das': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'SANJAY RUMA GHOSH': {'neg': 0.142,
#   'neu': 0.778,
#   'pos': 0.08,
#   'compound': -0.3316,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Akhtar Inamdar': {'neg': 0.429,
#   'neu': 0.571,
#   'pos': 0.0,
#   'compound': -0.3089,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Vikas Dave': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Shailesh Tiwari': {'neg': 0.0,
#   'neu': 0.847,
#   'pos': 0.153,
#   'compound': 0.4696,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Nikhil Girme': {'neg': 0.0,
#   'neu': 0.487,
#   'pos': 0.513,
#   'compound': 0.2755,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Sandeep Mohan': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Ranveer jadhav': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'CA.Sunit Sethia, Burhanpur': {'neg': 0.375,
#   'neu': 0.625,
#   'pos': 0.0,
#   'compound': -0.5563,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'kanpuriya chacha': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.4404,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Mansi Gupta': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Shivesh Shukla': {'neg': 0.0,
#   'neu': 0.715,
#   'pos': 0.285,
#   'compound': 0.4927,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'YOR TIME': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.5719,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Kushan Verma': {'neg': 0.0,
#   'neu': 0.256,
#   'pos': 0.744,
#   'compound': 0.4404,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Vijay Bahadur Singh': {'neg': 0.451,
#   'neu': 0.549,
#   'pos': 0.0,
#   'compound': -0.6249,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'manoranjan dash': {'neg': 0.649,
#   'neu': 0.351,
#   'pos': 0.0,
#   'compound': -0.5719,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'APS MANAGEMENT': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Razi Ahmad': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'sumita mahapatra': {'neg': 0.382,
#   'neu': 0.618,
#   'pos': 0.0,
#   'compound': -0.6525,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Hitesh Jaiswal': {'neg': 0.362,
#   'neu': 0.44,
#   'pos': 0.198,
#   'compound': -0.3021,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Yogesh Laddha': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'preman nair': {'neg': 0.355,
#   'neu': 0.645,
#   'pos': 0.0,
#   'compound': -0.296,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Sachin Hanwate': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.6249,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Prabir Dutta': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.296,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Mr Pankaj Hurmade': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Mr. N Roy': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.4215,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'sudhanshu shroti': {'neg': 0.293,
#   'neu': 0.707,
#   'pos': 0.0,
#   'compound': -0.4404,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Narendra doddamani': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'PINTU KUMAR': {'neg': 0.0,
#   'neu': 0.263,
#   'pos': 0.737,
#   'compound': 0.4215,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Anirudh P K': {'neg': 0.172,
#   'neu': 0.681,
#   'pos': 0.147,
#   'compound': -0.2263,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'SUDARSAN CHENNOZUU': {'neg': 0.448,
#   'neu': 0.552,
#   'pos': 0.0,
#   'compound': -0.7574,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Yogesh Jadhav': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'Suraj Burnwal': {'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0,
#   'compound': 0.0,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'PINAKI RANJAN SAHA': {'neg': 0.0,
#   'neu': 0.0,
#   'pos': 1.0,
#   'compound': 0.4404,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'MEHUL KORAT': {'neg': 0.074,
#   'neu': 0.926,
#   'pos': 0.0,
#   'compound': -0.3392,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442},
#  'A Google user': {'neg': 0.0,
#   'neu': 0.579,
#   'pos': 0.421,
#   'compound': 0.6249,
#   'roberta_neg': 0.999512,
#   'roberta_pos': 0.00048778442}}

# %%
results_df=pd.DataFrame(result).T
results_df=results_df.reset_index().rename(columns={"index":"userName"})
results_df=results_df.merge(df, how="left")

# %%
results_df.columns
# Out:
# Index(['userName', 'neg', 'neu', 'pos', 'compound', 'roberta_neg',
#        'roberta_pos', 'reviewId', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt'],
#       dtype='object')

# %%
sns.pairplot(data=results_df,
             vars=['neg', 'neu', 'pos', 'compound', 'roberta_neg',
                  'roberta_pos'],
             hue="score",
             palette="tab10")
