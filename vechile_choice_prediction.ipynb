# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaykbenny/Akshay-k-Benny/blob/main/vechile_choice_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("sample_submission.csv")
# Out:
#     CustomerID           vehicle_choice
# 0  CusID_00000                    Sedan
# 1  CusID_00001  Compact Utility Vehicle
# 2  CusID_00002             Sports Sedan
# 3  CusID_00003                Sportscar
# 4  CusID_00004   Sports Utility Vehicle

# %%
df_test=pd.read_csv("test.csv")

# %%
df_train=pd.read_csv("train.csv")

# %%
df_test.head(10)
# Out:
#     CustomerID   Age         Gender           City is_Married  family_size  \
# 0  CusID_30000  32.0         Female          Delhi    Married          6.0
# 1  CusID_30001  22.0           Male          Perth   Divorced          4.0
# 2  CusID_30002  46.0         Female      Barcelona    Married          2.0
# 3  CusID_30003  35.0            NaN   Kuala Lampur     Single          1.0
# 4  CusID_30004  48.0           Male         Sydney    Married          3.0
# 5  CusID_30005  57.0           Male      Vancouver   Divorced          2.0
# 6  CusID_30006  23.0           Male      Barcelona   Divorced          2.0
# 7  CusID_30007  53.0           Male         Sydney   Divorced          3.0
# 8  CusID_30008  27.0  Not_Specified  New York City   Divorced          4.0
# 9  CusID_30009  36.0           Male         Sydney    Married          2.0
#
#    height  annual_income          job is_physically_ok has_taken_car_loan  \
# ...

# %%
df_test.shape
# Out:
# (5000, 12)

# %%
df_test.isnull()
# Out:
#       CustomerID    Age  Gender   City  is_Married  family_size  height  \
# 0          False  False   False  False       False        False   False
# 1          False  False   False  False       False        False   False
# 2          False  False   False  False       False        False    True
# 3          False  False    True  False       False        False   False
# 4          False  False   False  False       False        False   False
# ...          ...    ...     ...    ...         ...          ...     ...
# 4995       False  False   False  False        True        False   False
# 4996       False  False   False   True       False        False   False
# 4997       False  False   False  False       False        False   False
# 4998       False  False   False  False       False        False   False
# 4999       False  False   False  False       False        False   False
#
#       annual_income    job  is_physically_ok  has_taken_car_loan  \
# ...

# %%
df_test.isnull().sum()
# Out:
# CustomerID                 0
# Age                       67
# Gender                    81
# City                      72
# is_Married                85
# family_size               73
# height                    67
# annual_income             78
# job                       74
# is_physically_ok          66
# has_taken_car_loan        61
# preferable_fuel_choice    83
# dtype: int64

# %%
df_test.dtypes
# Out:
# CustomerID                 object
# Age                       float64
# Gender                     object
# City                       object
# is_Married                 object
# family_size               float64
# height                    float64
# annual_income             float64
# job                        object
# is_physically_ok           object
# has_taken_car_loan         object
# preferable_fuel_choice     object
# dtype: object

# %%
df_train.shape
# Out:
# (30000, 13)

# %%
df_train.head(10)
# Out:
#     CustomerID   Age         Gender           City is_Married  family_size  \
# 0  CusID_00000  36.0           Male  New York City   Divorced          2.0
# 1  CusID_00001  15.0         Female  New York City     Single          1.0
# 2  CusID_00002  55.0           Male          Paris    Married          2.0
# 3  CusID_00003  23.0           Male      Vancouver   Divorced          3.0
# 4  CusID_00004  23.0  Not_Specified      Vancouver     Single          1.0
# 5  CusID_00005  46.0         Female      Vancouver   Divorced          4.0
# 6  CusID_00006  35.0  Not_Specified      Barcelona    Married          2.0
# 7  CusID_00007  15.0           Male      Vancouver     Single          1.0
# 8  CusID_00008  20.0           Male    Los Angeles     Single          1.0
# 9  CusID_00009  17.0  Not_Specified        Toronto     Single          1.0
#
#    height  annual_income       job is_physically_ok has_taken_car_loan  \
# ...

# %%
df_train.dtypes
# Out:
# CustomerID                 object
# Age                       float64
# Gender                     object
# City                       object
# is_Married                 object
# family_size               float64
# height                    float64
# annual_income             float64
# job                        object
# is_physically_ok           object
# has_taken_car_loan         object
# preferable_fuel_choice     object
# vehicle_choice             object
# dtype: object

# %%
df_train.isnull()
# Out:
#        CustomerID    Age  Gender   City  is_Married  family_size  height  \
# 0           False  False   False  False       False        False   False
# 1           False  False   False  False       False        False   False
# 2           False  False   False  False       False        False   False
# 3           False  False   False  False       False        False   False
# 4           False  False   False  False       False        False   False
# ...           ...    ...     ...    ...         ...          ...     ...
# 29995       False  False   False  False       False        False   False
# 29996       False  False   False  False       False        False   False
# 29997       False  False   False  False       False        False    True
# 29998       False   True   False  False       False        False   False
# 29999       False  False   False  False       False        False   False
#
#        annual_income    job  is_physically_ok  has_taken_car_loan  \
# ...

# %%
df_train.isnull().sum()
# Out:
# CustomerID                  0
# Age                       439
# Gender                    417
# City                      423
# is_Married                420
# family_size               414
# height                    431
# annual_income             419
# job                       428
# is_physically_ok          422
# has_taken_car_loan        431
# preferable_fuel_choice    428
# vehicle_choice              0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(df_train.iloc[:,:1],
                                               df_train.iloc[:,-1],
                                               test_size=0.3,
                                               random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21000 entries, 28465 to 23654
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  21000 non-null  object
# dtypes: object(1)
# memory usage: 328.1+ KB

# %%
x_train=x_train.iloc[:,1:]
x_test=x_test.iloc[:,1:]

# %%
make_train=x_train["CustomerID"].str.split("",expand=True)
make_test=x_test["CustomerID"].str.split("",expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CustomerID'
#
# The above exception was the direct cause of the following exception:
#
# ...
